# %%
import pandas as pd

# %%
class Wine():
    def __init__(self, id, name):
        self.id = id
        self.name = name
    
    def __str__(self):
        return f'{self.id} - {self.name}'

# %%
# Fetch a list of 1000 bottles of wine
filename = 'WineReviews.csv'
df = pd.read_csv(filename, index_col=0)

# Remove and brands that are NaN
df = df.dropna(subset=['brand'])

# Grab random subset of 1000 bottles
df = df.sample(n=bottles)
df.head()
# Out:
#                            asins            brand  \
# id
# AVpe4csNilAPnD_xP-O4         NaN   Margaritaville
# AVpieRqRLJeJML43mBQ9         NaN  Master of Mixes
# AVpfa-iW1cnluZ0-kehZ  B001ID2TPC     Fee Brothers
# AVpf-F_EilAPnD_xlTDm         NaN           Carmex
# AVphqaY4ilAPnD_x76_u  B010MHD1YM      Jose Cuervo
#
#                                                              categories  \
# id
# AVpe4csNilAPnD_xP-O4  Food,Beverages,Beer, Wine & Spirits,Cocktail M...
# AVpieRqRLJeJML43mBQ9  Food,Beverages,Beer, Wine & Spirits,Cocktail M...
# AVpfa-iW1cnluZ0-kehZ  Food,Beverages,Beer, Wine & Spirits,Cocktail M...
# AVpf-F_EilAPnD_xlTDm  Food,Beverages,Beer, Wine & Spirits,Beer,Whole...
# AVphqaY4ilAPnD_x76_u  Food & Beverage,Beverages,Cocktail Mixes,Food,...
#
#                                  dateAdded           dateUpdated  \
# id
# AVpe4csNilAPnD_xP-O4  2016-04-09T04:17:59Z  2017-09-23T02:53:07Z
# AVpieRqRLJeJML43mBQ9  2017-01-14T19:38:10Z  2018-01-02T21:13:49Z
# ...

# %%
# iterate over the dataframe and create a list of Wine objects
wines = []
for index, row in df.iterrows():
    wines.append(Wine(index, row['brand']))

# %%
[str(x) for x in wines[:10]]
# Out:
# ['AVpe4csNilAPnD_xP-O4 - Margaritaville',
#  'AVpieRqRLJeJML43mBQ9 - Master of Mixes',
#  'AVpfa-iW1cnluZ0-kehZ - Fee Brothers',
#  'AVpf-F_EilAPnD_xlTDm - Carmex',
#  'AVphqaY4ilAPnD_x76_u - Jose Cuervo',
#  'AVpf-F_EilAPnD_xlTDm - Carmex',
#  'AVpe5lZ-LJeJML43x1nN - Silver Spring',
#  'AVpf-F_EilAPnD_xlTDm - Carmex',
#  'AVpfBanOLJeJML430qYK - boomchugalug',
#  'AVpf-F_EilAPnD_xlTDm - Carmex']

# %%
len(wines)
# Out:
# 1000

# %%
class King():

    def __init__(self):
        self.prisoners = []
        self.wines = []
    
    def fuck_yeh_monarchy(self, prisoners, wines):
        self.prisoners = prisoners
        self.wines = wines
    
    def assemble_prisoners(self):
        return self.prisoners
    
    def go_to_cellar(self):
        return self.wines

# %%
class Prisoner():
    def __init__(self, name):
        self.name = name
        self.wine_to_tase = []

# %%
king = King()
king.fuck_yeh_monarchy([Prisoner(x) for x in range(10)], wines)

# %%
servants = king.assemble_prisoners()
wines = king.go_to_cellar()

# %%
# So we can kill up to 9 at a time
# 10 die for one bottle
# 0 die for one bottle

# So for each prisoner assign a bottle
